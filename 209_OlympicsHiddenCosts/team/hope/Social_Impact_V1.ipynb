# %% [markdown]
# # Week 4 — Logistic Regression & Classification Metrics
#
# ### *Sigmoid · ROC · PR · calibration · cost-sensitive thresholds* · **SOLUTIONS**
#
# ---
# **DATASCI 207 · Applied Machine Learning · UC Berkeley**

# %%
import os, sys, math, time, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
np.random.seed(207)
plt.rcParams.update({
    'figure.figsize': (8, 4.5),
    'axes.spines.top': False,
    'axes.spines.right': False,
    'axes.grid': True,
    'grid.alpha': 0.25,
})
from sklearn.datasets import load_breast_cancer, make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import (confusion_matrix, classification_report,
                              roc_auc_score, roc_curve,
                              precision_recall_curve, average_precision_score,
                              brier_score_loss)
from sklearn.calibration import calibration_curve
print('Python:', sys.version.split()[0],
      ' NumPy:', np.__version__,
      ' Pandas:', pd.__version__)
# Out:
# Python: 3.12.2  NumPy: 1.26.4  Pandas: 3.0.3

# %%
import pandas as pd

# Load the first sheet of the Excel file
df = pd.read_excel('your_file.xlsx')

# View the first 5 rows
print(df.head())
